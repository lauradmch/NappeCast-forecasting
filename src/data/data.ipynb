# %% [markdown]
# ### Stations

# %%
import requests
import pandas as pd

url = "https://hubeau.eaufrance.fr/api/v1/niveaux_nappes/stations"
params = {"size": 5000, "code_departement": 24}
headers = {"accept": "application/json"}

response = requests.get(url, params=params, headers=headers)
response.raise_for_status() 

data = response.json()
df = pd.DataFrame(data["data"])

print(data.get("count"), "résultats au total")
display(df.describe())
display(df.head())
# Out:
# {'count': 234, 'first': 'https://hubeau.eaufrance.fr/api/v1/niveaux_nappes/stations?code_departement=24&page=1&size=5000', 'last': None, 'prev': None, 'next': None, 'api_version': '1.4.3', 'data': [{'code_bss': '08081X0026/SE.20', 'urn_bss': 'http://services.ades.eaufrance.fr/pointeau/08081X0026/SE.20', 'date_debut_mesure': '1996-09-05', 'date_fin_mesure': '2026-07-14', 'code_commune_insee': '24255', 'nom_commune': 'Marquay', 'x': 1.148944586, 'y': 44.923232442, 'codes_bdlisa': ['348AA01'], 'urns_bdlisa': ['http://reseau.eaufrance.fr/geotraitements/bdlisa/files/entite/348AA01.pdf'], 'geometry': {'type': 'Point', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}}, 'coordinates': [1.14894458649071, 44.9232324420548]}, 'bss_id': 'BSS001YSAR', 'altitude_station': '154.0', 'nb_mesures_piezo': 7959, 'code_departement': '24', 'nom_departement': 'Dordogne', 'libelle_pe': 'COMBE BOYER (MARQUAY - 24)', 'profondeur_investigation': 87.0, 'codes_masse_eau_edl': ['FG108'], 'noms_masse_eau_edl': ['Calcaires, calcaires crayeux, grès, sables et marnes du Cénomanien au Coniacien inférieur des bassins versants de la Dordogne moyenne et de la Vézère'], 'urns_masse_eau_edl': ['http://www.sandre.eaufrance.fr/geo/MasseDEauSouterraine/FG108'], 'date_maj': 'Tue Mar 18 21:37:09 CET 2025'}, {'code_bss': '07598X0005/A81', 'urn_bss': 'http://services.ades.eaufrance.fr/pointeau/07598X0005/A81', 'date_debut_mesure': '1996-07-30', 'date_fin_mesure': '2026-07-13', 'code_commune_insee': '24555', 'nom_commune': 'Tourtoirac', 'x': 1.07042, 'y': 45.24972, 'codes_bdlisa': ['358AE07'], 'urns_bdlisa': ['http://reseau.eaufrance.fr/geotraitements/bdlisa/files/entite/358AE07.pdf'], 'geometry': {'type': 'Point', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}}, 'coordinates': [1.07042, 45.24972]}, 'bss_id': 'BSS001WDTX', 'altitude_station': '165.8', 'nb_mesures_piezo': 7212, 'code_departement': '24', 'nom_departement': 'Dordogne', 'libelle_pe': 'ROUGERIE A81 (TOURTOIRAC-24)', 'profondeur_investigation': 66.0, 'codes_masse_eau_edl': ['FG003'], 'noms_masse_eau_edl': ["Calcaires du Jurassique moyen des bassins versants de l'Isle et de la Dronne"], 'urns_masse_eau_edl': ['http://www.sandre.eaufrance.fr/geo/MasseDEauSouterraine/FG003'], 'date_maj': 'Tue Sep 03 07:12:40 CEST 2024'}, {'code_bss': '07847X0010/F1', 'urn_bss': 'http://services.ades.eaufrance.fr/pointeau/07847X0010/F1', 'date_debut_mesure': '1986-10-01', 'date_fin_mesure': '1986-12-10', 'code_commune_insee': '24085', 'nom_commune': 'La Cassagne', 'x': 1.318102185, 'y': 45.045603791, 'codes_bdlisa': ['358AE07'], 'urns_bdlisa': ['http://reseau.eaufrance.fr/geotraitements/bdlisa/files/entite/358AE07.pdf'], 'geometry': {'type': 'Point', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}}, 'coordinates': [1.3181021852846164, 45.045603791457445]}, 'bss_id': 'BSS001XCWC', 'altitude_station': '156.87', 'nb_mesures_piezo': 3, 'code_departement': '24', 'nom_departement': 'Dordogne', 'libelle_pe': 'F1', 'profondeur_investigation': 200.0, 'codes_masse_eau_edl': ['FG040'], 'noms_masse_eau_edl': ['Calcaires du Jurassique moyen des Causses du Quercy dans le bassin versant de la Vézère'], 'urns_masse_eau_edl': ['http://www.sandre.eaufrance.fr/geo/MasseDEauSouterraine/FG040'], 'date_maj': 'Fri Jun 28 07:31:38 CEST 2024'}, {'code_bss': '07345X0020/F1', 'urn_bss': 'http://services.ades.eaufrance.fr/pointeau/07345X0020/F1', 'date_debut_mesure': '2002-07-11', 'date_fin_mesure': '2012-04-04', 'code_commune_insee': '24119', 'nom_commune': 'Cherval', 'x': 0.403764079, 'y': 45.376158284, 'codes_bdlisa': None, 'urns_bdlisa': [], 'geometry': {'type': 'Point', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}}, 'coordinates': [0.403764079031951, 45.3761582838765]}, 'bss_id': 'BSS001VDVB', 'altitude_station': '148.0', 'nb_mesures_piezo': 566, 'code_departement': '24', 'nom_departement': 'Dordogne', 'libelle_pe': 'LA FEUILLA ...
# 234 résultats au total
#                 x           y  nb_mesures_piezo  profondeur_investigation
# count  234.000000  234.000000        234.000000                228.000000
# mean     0.688151   45.042011       1734.965812                166.714035
# std      0.321903    0.246209       2663.643967                155.380297
# min      0.016523   44.588493          0.000000                  0.000000
# 25%      0.419140   44.843795          1.000000                 58.125000
# 50%      0.690197   45.006581         14.500000                111.000000
# 75%      0.926058   45.224775       3868.750000                245.750000
# max      1.388338   45.672371       8301.000000                800.000000
#            code_bss                                            urn_bss  \
# 0  08081X0026/SE.20  http://services.ades.eaufrance.fr/pointeau/080...
# 1    07598X0005/A81  http://services.ades.eaufrance.fr/pointeau/075...
# 2     07847X0010/F1  http://services.ades.eaufrance.fr/pointeau/078...
# 3     07345X0020/F1  http://services.ades.eaufrance.fr/pointeau/073...
# 4     07818X0030/F1  http://services.ades.eaufrance.fr/pointeau/078...
#
#   date_debut_mesure date_fin_mesure code_commune_insee  \
# 0        1996-09-05      2026-07-14              24255
# 1        1996-07-30      2026-07-13              24555
# 2        1986-10-01      1986-12-10              24085
# 3        2002-07-11      2012-04-04              24119
# 4        1996-08-30      1996-08-30              24462
#
#                 nom_commune         x          y codes_bdlisa  \
# 0                   Marquay  1.148945  44.923232    [348AA01]
# 1                Tourtoirac  1.070420  45.249720    [358AE07]
# 2               La Cassagne  1.318102  45.045604    [358AE07]
# 3                   Cherval  0.403764  45.376158         None
# 4  Saint-Médard-de-Mussidan  0.332473  45.023305         None
#
#                                          urns_bdlisa  ... altitude_station  \
# 0  [http://reseau.eaufrance.fr/geotraitements/bdl...  ...            154.0
# 1  [http://reseau.eaufrance.fr/geotraitements/bdl...  ...            165.8
# 2  [http://reseau.eaufrance.fr/geotraitements/bdl...  ...           156.87
# 3                                                 []  ...            148.0
# 4                                                 []  ...             57.0
#
#   nb_mesures_piezo code_departement  nom_departement  \
# 0             7959               24         Dordogne
# 1             7212               24         Dordogne
# 2                3               24         Dordogne
# 3              566               24         Dordogne
# 4                1               24         Dordogne
#
#                      libelle_pe profondeur_investigation codes_masse_eau_edl  \
# 0    COMBE BOYER (MARQUAY - 24)                     87.0             [FG108]
# 1  ROUGERIE A81 (TOURTOIRAC-24)                     66.0             [FG003]
# 2                            F1                    200.0             [FG040]
# 3     LA FEUILLADE (CHERVAL-24)                    135.0            [FG073A]
# 4                           NaN                     70.0                None
#
#                                   noms_masse_eau_edl  \
# 0  [Calcaires, calcaires crayeux, grès, sables et...
# 1  [Calcaires du Jurassique moyen des bassins ver...
# 2  [Calcaires du Jurassique moyen des Causses du ...
# 3  [Multicouches calcaire captif du Turonien-Coni...
# 4                                               None
#
#                                   urns_masse_eau_edl  \
# 0  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 1  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 2  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 3  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 4                                                 []
#
#                         date_maj
# 0   Tue Mar 18 21:37:09 CET 2025
# 1  Tue Sep 03 07:12:40 CEST 2024
# 2  Fri Jun 28 07:31:38 CEST 2024
# 3  Fri Jun 28 07:31:38 CEST 2024
# 4  Fri Jun 28 07:31:38 CEST 2024
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Piezometre

# %%
url = "https://hubeau.eaufrance.fr/api/v1/niveaux_nappes/chroniques"
headers = {"accept": "application/json"}

df_p= []

for i, code in enumerate(df["code_bss"]):
    params = {"size": 5000, "code_bss": code}

    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status() 
    data = response.json()
    df_cache = pd.DataFrame(data["data"])

    df_p.append(df_cache)

    if i> 10 :
        break

piezometre_df = pd.concat(df_p, ignore_index=True)

print(len(piezometre_df), "résultats au total")
print( f"Début de la mesure {piezometre_df['date_mesure'].min}, fin de la mesure {piezometre_df['date_mesure'].max}")

display(piezometre_df.describe())
display(piezometre_df.head())
# Out:
# 21719 résultats au total
# Début de la mesure <bound method Series.min of 0        1996-09-05
# 1        1998-05-14
# 2        1999-08-17
# 3        2000-08-24
# 4        2001-10-17
#             ...
# 21714    2026-05-28
# 21715    2026-05-29
# 21716    2026-05-30
# 21717    2026-05-31
# 21718    2026-06-01
# Name: date_mesure, Length: 21719, dtype: str>, fin de la mesure <bound method Series.max of 0        1996-09-05
# 1        1998-05-14
# 2        1999-08-17
# 3        2000-08-24
# 4        2001-10-17
#             ...
# 21714    2026-05-28
# 21715    2026-05-29
# 21716    2026-05-30
# 21717    2026-05-31
# 21718    2026-06-01
# Name: date_mesure, Length: 21719, dtype: str>
#        timestamp_mesure  niveau_nappe_eau  profondeur_nappe
# count      2.171900e+04      21719.000000      21719.000000
# mean       1.449660e+12        120.350583         12.577143
# std        1.860413e+11         63.823619         12.734055
# min        3.544128e+11        -29.590000         -4.750000
# 25%        1.314662e+12         96.810000          3.210000
# 50%        1.456967e+12        152.240000          7.180000
# 75%        1.594526e+12        160.230000         15.045000
# max        1.784009e+12        174.690000         56.000000
#            code_bss      bss_id  \
# 0  08081X0026/SE.20  BSS001YSAR
# 1  08081X0026/SE.20  BSS001YSAR
# 2  08081X0026/SE.20  BSS001YSAR
# 3  08081X0026/SE.20  BSS001YSAR
# 4  08081X0026/SE.20  BSS001YSAR
#
#                                              urn_bss date_mesure  \
# 0  http://services.ades.eaufrance.fr/pointeau/080...  1996-09-05
# 1  http://services.ades.eaufrance.fr/pointeau/080...  1998-05-14
# 2  http://services.ades.eaufrance.fr/pointeau/080...  1999-08-17
# 3  http://services.ades.eaufrance.fr/pointeau/080...  2000-08-24
# 4  http://services.ades.eaufrance.fr/pointeau/080...  2001-10-17
#
#    timestamp_mesure  niveau_nappe_eau  mode_obtention  \
# 0      841881600000            152.52  Valeur mesurée
# 1      895104000000            152.93  Valeur mesurée
# 2      934848000000            152.93  Valeur mesurée
# 3      967075200000            152.98  Valeur mesurée
# 4     1003276800000            152.78  Valeur mesurée
#
#                       statut qualification code_continuite  \
# 0  Donnée contrôlée niveau 1      Correcte               2
# 1  Donnée contrôlée niveau 1      Correcte               2
# 2  Donnée contrôlée niveau 1      Correcte               2
# 3  Donnée contrôlée niveau 1      Correcte               2
# 4  Donnée contrôlée niveau 1      Correcte               2
#
#                  nom_continuite code_producteur  \
# 0  Point lié au point précédent             327
# 1  Point lié au point précédent             327
# 2  Point lié au point précédent             327
# 3  Point lié au point précédent             327
# 4  Point lié au point précédent             327
#
#                                   nom_producteur code_nature_mesure  \
# 0  Service Géologique Régional d'Aquitaine (327)                  0
# 1  Service Géologique Régional d'Aquitaine (327)                  0
# 2  Service Géologique Régional d'Aquitaine (327)                  0
# 3  Service Géologique Régional d'Aquitaine (327)                  0
# 4  Service Géologique Régional d'Aquitaine (327)                  0
#
#   nom_nature_mesure  profondeur_nappe
# 0          Inconnue              1.40
# 1          Inconnue              0.99
# 2          Inconnue              0.99
# 3          Inconnue              0.94
# 4          Inconnue              1.14
